# %%
# Step 1: Import libraries
import numpy as np
import pandas as pd

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Step 2: Load dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Step 3: Convert regression target → classification
# (Simple: above median = 1, below = 0)
y_class = (y > np.median(y)).astype(int)

# Step 4: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_class, test_size=0.2, random_state=42
)

# Step 5: Weak learner (Decision Stump)
base_model = DecisionTreeClassifier(max_depth=1)

# Step 6: AdaBoost Model
model = AdaBoostClassifier(
    estimator=base_model,
    n_estimators=50,
    learning_rate=1.0,
    random_state=42
)

# Step 7: Train model
model.fit(X_train, y_train)

# Step 8: Predictions
y_pred = model.predict(X_test)

# Step 9: Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8386627906976745
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84      2077
#            1       0.86      0.81      0.83      2051
#
#     accuracy                           0.84      4128
#    macro avg       0.84      0.84      0.84      4128
# weighted avg       0.84      0.84      0.84      4128
